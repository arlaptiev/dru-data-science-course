# %% [markdown]
# # Matplotlib Introduction 📈

# %%
from matplotlib import pylab
import numpy as np

pylab.__version__
# Out:
# '1.15.1'

# %%
x = np.linspace(0, 10, 25)
y = x  * x + 2

# %%
pylab.plot(x, y, 'r') # r for red

# %% [markdown]
# ### Drawing a subgraph

# %%
pylab.subplot(1,2,1) # params - (rows, colums, indexes)
pylab.plot(x,y,'r--')

pylab.subplot(1,2,2)
pylab.plot(y, x, 'g--')

# %%
pylab.subplot(1,2,1) # params - (rows, colums, indexes)
pylab.plot(x,y,'r--')

pylab.subplot(1,2,1)
pylab.plot(y, x, 'g--')
# Out:
# C:\ProgramFiles\Anaconda\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Operation description

# %%
from matplotlib import pyplot as plt

# %%
fig = plt.figure()

axis = fig.add_axes([0.5, 0.1, 0.8, 0.8]) # @params: left, right, width, height of canvas

axis.plot(x, y, 'r')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x,y, 'r')

# %% [markdown]
# ### Draw another picture or graph inside another graph

# %%
fig = plt.figure(figsize=(16,9), dpi=300) #dpi for quality

axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) # big axes
axes2 = fig.add_axes([0.2,0.5,0.4,0.3]) # small canvas

axes1.plot(x,y, 'r')
axes2.plot(y,x, 'g')

# %%
fig, axes = plt.subplots()

axes.set_xlabel('x-label')
axes.set_ylabel('y-label')

axes.set_title('title')


axes.plot(x, x**2, 'y')
axes.plot(x, x**3, 'b')

axes.legend(['label1', 'label2'], loc=2)

# %% [markdown]
# ### Line color, transparence, and more

# %%
fig, axes = plt.subplots(dpi=150)

# aplha for transparency
axes.plot(x, x**2, color='red', alpha=0.5)
axes.plot(x, x+2, color='#1155dd', alpha=0.5)
axes.plot(x, x+3, color='green', alpha=0.1)

# %%
fig, axes = plt.subplots(dpi=100)

axes.plot(x, x+1, color='blue', linewidth = 2)
axes.plot(x, x+2, color='blue', lw = 1)
axes.plot(x, x+3, color='blue', lw = 0.5)
axes.plot(x, x+4, color='blue', lw = 0.1)

# %%
fig, axes = plt.subplots(dpi=100)

axes.plot(x, x+1, color='yellow', lw = 3, linestyle='-')
axes.plot(x, x+2, color='yellow', lw = 3, ls='-.')
axes.plot(x, x+3, color='yellow', lw = 3, ls=':')

line, = axes.plot(x, x+4, color='blue', lw=2)
line.set_dashes([5,10,15,10])

line, = axes.plot(x, x+5, color='blue', lw=2)
line.set_dashes([5,10,15,3])

line, = axes.plot(x, x+6, color='blue', lw=2)
line.set_dashes([5,10,4,10])

# %%
fig, axes = plt.subplots(dpi=100)

axes.plot(x, x+1, color='blue')
axes.plot(x, x+2, color='blue', marker='o')
axes.plot(x, x+3, color='blue', marker='+')
axes.plot(x, x+4, color='blue', marker='s')
axes.plot(x, x+5, color='blue', marker='1')

axes.plot(x, x+6, color='blue', marker='o', markersize=13)
axes.plot(x, x+7, color='blue', marker='s', markerfacecolor='red')

# %% [markdown]
# ### Limiting canvas grid and axis range

# %%
fig, Axes = plt.subplots(1,2, figsize=(10,5))

Axes[0].plot(x, x**2, x, x**3, lw=2)
Axes[0].grid(True)

Axes[1].plot(x, x**2, x, x**3, lw=2)
Axes[1].set_ylim([0,60])
Axes[1].set_xlim([2,5])
# Out:
# (2, 5)

# %% [markdown]
# ## Other 2D Graphics

# %%
n = np.arange(6)

fig, axes = plt.subplots(1,4, figsize=(16,5))

axes[0].set_title('scatter')
axes[0].scatter(x, x + np.random.random(len(x)))

axes[1].set_title('step')
axes[1].step(n, n**2, lw=2)

axes[2].set_title('bar')
axes[2].bar(n, n**2, align='center', width=0.9, alpha=0.5)

axes[3].set_title('fill_between')
axes[3].fill_between(x, x**2, x**3, color='green', alpha=0.5)

# %% [markdown]
# ### Radar chart

# %%
fig = plt.figure(figsize=(6,6))

ax = fig.add_axes([0.0, 0.0, 1, 1], polar=True)
t = np.linspace(0, 2 * np.pi, 100)
ax.plot(t, t * 2, color='blue', lw=2)

# %% [markdown]
# ### Histogram

# %%
n = np.random.randn(100000)

fig, axes = plt.subplots(1,2, figsize=(12, 4))

axes[0].set_title("Default histogram")
axes[0].hist(n, bins=1000)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=7, color='orange')
# Out:
# (array([2.0000e+01, 1.4480e+03, 1.9301e+04, 6.7238e+04, 9.6114e+04,
#         9.9878e+04, 1.0000e+05]),
#  array([-4.8191268 , -3.50391293, -2.18869906, -0.8734852 ,  0.44172867,
#          1.75694254,  3.07215641,  4.38737028]),
#  <a list of 7 Patch objects>)

# %% [markdown]
# ### Contour maps

# %%
import matplotlib.cm as cm

# %%
delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X-1)**2 - (Y-1)**2)
Z = (Z1-Z2) * 2

print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
ax.clabel(CS, inlint=1, fontsize=10)
ax.set_title('countour map')
# Out:
# Text(0.5,1,'countour map')

# %% [markdown]
# ### 3D Map

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
fig = plt.figure(figsize=(14, 6))

ax = fig.add_subplot(1,2,1, projection='3d')
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, lw=0)

# %% [markdown]
# ### Pie chart

# %%
languages = 'Python', 'Java', 'PHP', 'JavaScript', 'C#', 'C++'
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ['#1f77b4', '#ff7f03', '#2ca02c', '#d62728', '#9467bd', '#8c564b']

# %%
# explode 1st slice
explode = (0.1, 0, 0, 0, 0, 0)

plt.pie(popularity, explode=explode, labels=languages, autopct='%1.1f%%', colors=colors, shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x2ce1c410ef0>,
# ...
#  [Text(-1.15187,-0.336432,'Python'),
#   Text(0.502519,-0.978506,'Java'),
#   Text(1.09717,0.0788901,'PHP'),
#   Text(0.754341,0.800606,'JavaScript'),
#   Text(0.0670183,1.09796,'C#'),
#   Text(-0.59933,0.92239,'C++')],
#  [Text(-0.671926,-0.196252,'31.3%'),
#   Text(0.274101,-0.533731,'24.8%'),
#   Text(0.598455,0.0430309,'12.4%'),
#   Text(0.411459,0.436694,'11.3%'),
#   Text(0.0365554,0.598885,'10.8%'),
#   Text(-0.326907,0.503122,'9.4%')])
